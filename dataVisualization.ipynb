# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import missingno

# %%
df  = pd.read_csv("MARKET_Car_Prices.csv")

# %%
df.head()
# Out:
#           make fuel_type aspiration num_of_doors   body_style drive_wheels  \
# 0  alfa-romero       gas        std          two  convertible          rwd
# 1  alfa-romero       gas        std          two  convertible          rwd
# 2  alfa-romero       gas        std          two    hatchback          rwd
# 3         audi       gas        std         four        sedan          fwd
# 4         audi       gas        std         four        sedan          4wd
#
#   engine_location  wheel_base  length  width  ...  engine_size  fuel_system  \
# 0           front        88.6   168.8   64.1  ...          130         mpfi
# 1           front        88.6   168.8   64.1  ...          130         mpfi
# 2           front        94.5   171.2   65.5  ...          152         mpfi
# 3           front        99.8   176.6   66.2  ...          109         mpfi
# 4           front        99.4   176.6   66.4  ...          136         mpfi
#
# ...

# %%
df.shape
# Out:
# (205, 24)

# %%
"""
make - Mark of car
fuel_type - Fuel type (gas/disel)
aspiration - Engine aspiration (standard/turbo)
num_of_doors - Number of doors
body_style - Car body style
drive_wheels - Car drive wheels
engine_location - Location of engine
wheel_base - Base of wheel
length - Car lenght
width - Car width
height - Car height
curb_weight - The weight of the car
engine_type - Type of engine
num_of_cylinders - Number of Cylinders
engine_size - Size of engine
fuel_system - Fuel system
bore - The diameter of cylinder
stroke - Engine stroke
compression_ratio - Compression Ratio
horsepower - Horsepower
peak_rpm - Peak revolutions per minute
city_mpg - Number miles per gallon of fuel consumed during city driving
highway_mpg - Number miles per gallon of fuel consumed during highway driving
price - Car price
"""
# Out:
# '\nmake - Mark of car\nfuel_type - Fuel type (gas/disel)\naspiration - Engine aspiration (standard/turbo)\nnum_of_doors - Number of doors\nbody_style - Car body style\ndrive_wheels - Car drive wheels\nengine_location - Location of engine\nwheel_base - Base of wheel\nlength - Car lenght\nwidth - Car width\nheight - Car height\ncurb_weight - The weight of the car\nengine_type - Type of engine\nnum_of_cylinders - Number of Cylinders\nengine_size - Size of engine\nfuel_system - Fuel system\nbore - The diameter of cylinder\nstroke - Engine stroke\ncompression_ratio - Compression Ratio\nhorsepower - Horsepower\npeak_rpm - Peak revolutions per minute\ncity_mpg - Number miles per gallon of fuel consumed during city driving\nhighway_mpg - Number miles per gallon of fuel consumed during highway driving\nprice - Car price\n'

# %%
df.dtypes
# Out:
# make                  object
# fuel_type             object
# aspiration            object
# num_of_doors          object
# body_style            object
# drive_wheels          object
# engine_location       object
# wheel_base           float64
# length               float64
# width                float64
# height               float64
# curb_weight            int64
# engine_type           object
# num_of_cylinders      object
# engine_size            int64
# fuel_system           object
# bore                 float64
# stroke               float64
# compression_ratio    float64
# horsepower           float64
# peak_rpm             float64
# city_mpg               int64
# highway_mpg            int64
# price                float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# make                 0
# fuel_type            0
# aspiration           0
# num_of_doors         2
# body_style           0
# drive_wheels         0
# engine_location      0
# wheel_base           0
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          0
# num_of_cylinders     0
# engine_size          0
# fuel_system          0
# bore                 4
# stroke               4
# compression_ratio    0
# horsepower           2
# peak_rpm             2
# city_mpg             0
# highway_mpg          0
# price                4
# dtype: int64

# %%
# df = df[~df.isnull().any(axis=1)]
# df.isnull().sum()

# %%
{x:df[x].duplicated().sum() for x in df}
# Out:
# {'make': 183,
#  'fuel_type': 203,
#  'aspiration': 203,
#  'num_of_doors': 202,
#  'body_style': 200,
#  'drive_wheels': 202,
#  'engine_location': 203,
#  'wheel_base': 152,
#  'length': 130,
#  'width': 161,
#  'height': 156,
#  'curb_weight': 34,
#  'engine_type': 198,
#  'num_of_cylinders': 198,
#  'engine_size': 161,
#  'fuel_system': 197,
#  'bore': 166,
#  'stroke': 168,
#  'compression_ratio': 173,
#  'horsepower': 145,
#  'peak_rpm': 181,
#  'city_mpg': 176,
#  'highway_mpg': 175,
#  'price': 18}

# %%
missingno.bar(df)
plt.show()

# %%
missingno.matrix(df)
# Out:
# <Axes: >

# %%
missingno.heatmap(df)
plt.show()

# %%
num_cols = df.dtypes[df.dtypes!="O"].index.tolist()

# %%
num_cols
# Out:
# ['wheel_base',
#  'length',
#  'width',
#  'height',
#  'curb_weight',
#  'engine_size',
#  'bore',
#  'stroke',
#  'compression_ratio',
#  'horsepower',
#  'peak_rpm',
#  'city_mpg',
#  'highway_mpg',
#  'price']

# %%
df[num_cols]
# Out:
#      wheel_base  length  width  height  curb_weight  engine_size  bore  \
# 0          88.6   168.8   64.1    48.8         2548          130  3.47
# 1          88.6   168.8   64.1    48.8         2548          130  3.47
# 2          94.5   171.2   65.5    52.4         2823          152  2.68
# 3          99.8   176.6   66.2    54.3         2337          109  3.19
# 4          99.4   176.6   66.4    54.3         2824          136  3.19
# ..          ...     ...    ...     ...          ...          ...   ...
# 200       109.1   188.8   68.9    55.5         2952          141  3.78
# 201       109.1   188.8   68.8    55.5         3049          141  3.78
# 202       109.1   188.8   68.9    55.5         3012          173  3.58
# 203       109.1   188.8   68.9    55.5         3217          145  3.01
# 204       109.1   188.8   68.9    55.5         3062          141  3.78
#
#      stroke  compression_ratio  horsepower  peak_rpm  city_mpg  highway_mpg  \
# ...

# %%
for num_col in num_cols:
    sns.displot(df[num_col], kde=True)
    plt.show()

# %%
sns.distplot(df["price"])
# Out:
# <ipython-input-59-d7dbcdc4e35d>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["price"])
# <Axes: xlabel='price', ylabel='Density'>

# %%
df[df["price"]==0].shape
# Out:
# (0, 24)

# %%
df_sorted = df.sort_values("price", ascending=False)

# %%
df_sorted.columns
# Out:
# Index(['make', 'fuel_type', 'aspiration', 'num_of_doors', 'body_style',
#        'drive_wheels', 'engine_location', 'wheel_base', 'length', 'width',
#        'height', 'curb_weight', 'engine_type', 'num_of_cylinders',
#        'engine_size', 'fuel_system', 'bore', 'stroke', 'compression_ratio',
#        'horsepower', 'peak_rpm', 'city_mpg', 'highway_mpg', 'price'],
#       dtype='object')

# %%
plt.bar(df_sorted["make"].head(), df_sorted["price"].head())
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# The cheapest car markes

# %%
dfsna=df_sorted.dropna()

plt.bar(dfsna["make"].tail(),dfsna["price"].tail())
plt.title("The cheapest car markes")
# Out:
# Text(0.5, 1.0, 'The cheapest car markes')

# %% [markdown]
# Top markes

# %%
top_car = df['make'].value_counts().head(5).index.tolist()

# %%
top_car
# Out:
# ['toyota', 'nissan', 'mazda', 'mitsubishi', 'honda']

# %% [markdown]
# Corelation between num_of_cylinders and highway_mpg

# %%
df['num_of_cylinders'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
# replace string values to int for num_of_cylinders
df['num_of_cylinders'] =df['num_of_cylinders'].map({"two":2, "three":3, "four":4,"five":5,"six":6, "eight":8, "twelve":12})

# %%
df['num_of_cylinders'].unique()
# Out:
# array([ 4,  6,  5,  3, 12,  2,  8])

# %%
df['num_of_cylinders'].corr(df['highway_mpg'])
# Out:
# -0.466665920137387

# %%
plt.scatter(df['num_of_cylinders'], df['highway_mpg'],marker="<", color="b", label="highway")
plt.scatter(df['num_of_cylinders'], df['city_mpg'],marker=">", color="r", label="city")
plt.xlabel("num_of_cylinders")
plt.ylabel("miles_per_galon")
plt.legend()
plt.show()

# %%
"""
Cars with 3 and 4 cylinders can drive longest miles per gallon.
"""

# %%
# replace string values to int for engine_location
df['engine_location'] =df['engine_location'].map({"front":0, "rear":1})

# %%
df['engine_location'].unique()
# Out:
# array([0, 1])

# %%
plt.scatter(df['price'], df['highway_mpg'])
plt.show()

# %%
# big correlation between price and highway_mpg
df['price'].corr(df['highway_mpg'])
# Out:
# -0.704692265058953

# %%
df['make'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
makes =df['make'].map({'alfa-romero': 0, 'audi': 1, 'bmw': 2, 'chevrolet': 3, 'dodge': 4, 'honda': 5, 'isuzu': 6, 'jaguar': 7, 'mazda': 8, 'mercedes-benz': 9, 'mercury': 10, 'mitsubishi': 11, 'nissan': 12, 'peugot': 13, 'plymouth': 14, 'porsche': 15, 'renault': 16, 'saab': 17, 'subaru': 18, 'toyota': 19, 'volkswagen': 20, 'volvo': 21})
makes.corr(df['price'])
# Out:
# -0.1636463329630027

# %%
plt.scatter(makes, df['price'])
plt.show()

# %%
"""
As we can see correlation between make and price is low, so car's make doesn't reflect to it's price
"""

# %%
hm = sns.heatmap(df.corr(numeric_only = True), cmap="crest")
hm.set(title = "Correlation matrix of dataset\n")
# Out:
# [Text(0.5, 1.0, 'Correlation matrix of dataset\n')]
